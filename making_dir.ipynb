# %% [markdown]
# <a href="https://colab.research.google.com/github/kazzastic/BreastCancer-Deep-Learning/blob/master/making_dir.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import shutil
import glob

# %%
key = os.listdir("/content/drive/My Drive/PATCHES")
cancer = "/content/drive/My Drive/patches_sort/cancer"
normal = "/content/drive/My Drive/patches_sort/normal"
benign = "/content/drive/My Drive/patches_sort/benign"
c,n,b = 4367,3220,4832

for i in range(12419, len(key)):
  if key[i].startswith("cancer"):
    key[i] = "/content/drive/My Drive/PATCHES/"+key[i]
    shutil.copy(key[i], cancer)
    c+=1
  elif key[i].startswith("normal"):
    key[i] = "/content/drive/My Drive/PATCHES/"+key[i]
    shutil.copy(key[i], normal)
    n+=1
  else:
    key[i] = "/content/drive/My Drive/PATCHES/"+key[i]
    shutil.copy(key[i], benign)
    b+=1
  print("cancer = {}, normal = {}, benign = {}" .format(c, n, b))
# Out:
# cancer = 4368, normal = 3220, benign = 4832
# cancer = 4368, normal = 3220, benign = 4833
# cancer = 4369, normal = 3220, benign = 4833
# cancer = 4370, normal = 3220, benign = 4833
# cancer = 4371, normal = 3220, benign = 4833
# cancer = 4371, normal = 3220, benign = 4834
# cancer = 4372, normal = 3220, benign = 4834
# cancer = 4373, normal = 3220, benign = 4834
# cancer = 4374, normal = 3220, benign = 4834
# cancer = 4375, normal = 3220, benign = 4834
# cancer = 4375, normal = 3220, benign = 4835
# cancer = 4376, normal = 3220, benign = 4835
# cancer = 4377, normal = 3220, benign = 4835
# cancer = 4378, normal = 3220, benign = 4835
# cancer = 4379, normal = 3220, benign = 4835
# cancer = 4380, normal = 3220, benign = 4835
# cancer = 4381, normal = 3220, benign = 4835
# cancer = 4382, normal = 3220, benign = 4835
# cancer = 4383, normal = 3220, benign = 4835
# cancer = 4384, normal = 3220, benign = 4835
# cancer = 4385, normal = 3220, benign = 4835
# ...

# %%
key = os.listdir("/content/drive/My Drive/PATCHES")
key[0]
# Out:
# 'normal_04-A_0439_1.RIGHT_MLO.LJPEG.1-x3322_y604_w604_h604_imgfrac0.25_stridefrac0.5.jpg'

# %%
key = os.listdir("/content/drive/My Drive/PATCHES")
cancer = "/content/drive/My Drive/patches_sort/cancer"
normal = "/content/drive/My Drive/patches_sort/normal"
benign = "/content/drive/My Drive/patches_sort/benign"
c,n,b = 0,0,0

for i in range(10):
  if key[i].startswith("cancer"):
    key[i] = "/content/drive/My Drive/PATCHES/"+key[i]
    shutil.copy(key[i], cancer)
    c+=1
  elif key[i].startswith("normal"):
    key[i] = "/content/drive/My Drive/PATCHES/"+key[i]
    shutil.copy(key[i], normal)
    n+=1
  else:
    key[i] = "/content/drive/My Drive/PATCHES/"+key[i]
    shutil.copy(key[i], benign)
    b+=1
  print("cancer = {}, normal = {}, benign = {}" .format(c, n, b))
# Out:
# cancer = 0, normal = 1, benign = 0
# cancer = 0, normal = 2, benign = 0
# cancer = 0, normal = 3, benign = 0
# cancer = 0, normal = 4, benign = 0
# cancer = 0, normal = 5, benign = 0
# cancer = 0, normal = 6, benign = 0
# cancer = 0, normal = 7, benign = 0
# cancer = 0, normal = 8, benign = 0
# cancer = 0, normal = 9, benign = 0
# cancer = 0, normal = 10, benign = 0
